-- %%
--select * from read_files("/Volumes/dev_agents/naval/raw/housing.csv");


select * from sony_dev.gold.gold_customer_spending_summary where customer_country = :country and gender = :gender;

create table sony_dev.gold.sales (id int, product string, price int);

insert into sony_dev.gold.sales values (2, 'bike', 20000);



select * from sony_dev.gold.sales
