-- %%
select *, ai_analyze_sentiment(review) as senti from samples.bakehouse.media_customer_reviews

-- %%
SELECT
  path,
  ai_parse_document(content)
FROM READ_FILES('/Volumes/sony_dev/naval/raw/invoice-dmc039-data-master-consulting-private-limited-jellyfish-training-us.pdf', format => 'binaryFile');

-- %%
SELECT
  path,
  ai_parse_document(content)
FROM READ_FILES('/Volumes/sony_dev/naval/raw/download.jpeg', format => 'binaryFile');

-- %%
SELECT ai_analyze_sentiment('I am happy');

-- %%
SELECT ai_classify("My password is leaked.", ARRAY("urgent", "not urgent"))

-- %%
 SELECT ai_extract('John Doe lives in New York and works for Acme Corp.',
    array('person', 'location', 'organization')
  );

-- %%
 SELECT ai_extract('John Doe, email is john@gmail.com and works for Acme Corp.',
    array('person', 'location', 'organization','email')
  );

-- %%
SELECT ai_translate('Hello, how are you?', 'Telugu');
